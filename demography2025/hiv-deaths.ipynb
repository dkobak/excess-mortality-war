# %% [markdown]
# # War fatalities in Russia in 2022--2023 estimated via excess male mortality
# ## HIV deaths

# %%
# %matplotlib inline

import numpy as np
import pylab as plt
import pandas as pd

plt.style.use("mpl_style.txt")

# %%
df = pd.read_excel('../deaths-hiv/deaths-hiv.xlsx', skiprows=1, index_col=0)

male   = df.values[2:-1, 1::3]
female = df.values[2:-1, 2::3]

age   = np.arange(1, 101)
years = np.arange(2006, 2023)

df
# Out:
#                           2006 Unnamed: 2 Unnamed: 3               2007  \
# NaN          Мужчины и женщины    Мужчины    Женщины  Мужчины и женщины
# Всего                     2464       1877        587               3626
# 1 год                        4          3          1                  0
# 2 года                       1          0          1                  1
# 3 года                       0          0          0                  5
# ...                        ...        ...        ...                ...
# 97 лет                       0          0          0                  0
# 98 лет                       0          0          0                  0
# 99 лет                       0          0          0                  0
# 100 и более                  0          0          0                  1
# Неизвестно                   4          3          1                 10
#
#             Unnamed: 5 Unnamed: 6               2008 Unnamed: 8 Unnamed: 9  \
# NaN            Мужчины    Женщины  Мужчины и женщины    Мужчины    Женщины
# Всего             2762        864               4460       3404       1056
# 1 год                0          0                  4          4          0
# 2 года               1          0                  0          0          0
# 3 года               2          3                  3          1          2
# ...                ...        ...                ...        ...        ...
# 97 лет               0          0                  0          0          0
# 98 лет               0          0                  0          0          0
# 99 лет               0          0                  0          0          0
# 100 и более          1          0                  0          0          0
# Неизвестно           8          2                  8          6          2
#
#                           2009  ... Unnamed: 42               2020  \
# NaN          Мужчины и женщины  ...     Женщины  Мужчины и женщины
# Всего                     5640  ...        6694              18499
# 1 год                        2  ...           1                  2
# 2 года                       1  ...           1                  0
# 3 года                       1  ...           1                  0
# ...                        ...  ...         ...                ...
# 97 лет                       0  ...           0                  0
# 98 лет                       0  ...           0                  0
# 99 лет                       0  ...           0                  0
# 100 и более                  0  ...           0                  0
# Неизвестно                   7  ...          33                 79
#
#             Unnamed: 44 Unnamed: 45               2021 Unnamed: 47  \
# NaN             Мужчины     Женщины  Мужчины и женщины     Мужчины
# Всего             12204        6295              16914       11118
# 1 год                 1           1                  2           1
# 2 года                0           0                  2           1
# 3 года                0           0                  1           0
# ...                 ...         ...                ...         ...
# 97 лет                0           0                  0           0
# 98 лет                0           0                  0           0
# 99 лет                0           0                  0           0
# 100 и более           0           0                  0           0
# Неизвестно           64          15                 61          43
#
#             Unnamed: 48               2022 Unnamed: 50 Unnamed: 51
# NaN             Женщины  Мужчины и женщины     Мужчины     Женщины
# Всего              5796              15804       10344        5460
# 1 год                 1                  0           0           0
# 2 года                1                  3           3           0
# 3 года                1                  0           0           0
# ...                 ...                ...         ...         ...
# 97 лет                0                  0           0           0
# 98 лет                0                  0           0           0
# 99 лет                0                  0           0           0
# 100 и более           0                  0           0           0
# Неизвестно           18                 47          38           9
#
# [103 rows x 51 columns]

# %%
df = pd.read_excel('../deaths-hiv/deaths-hiv-2023.xlsx', skiprows=1)

male2023 = df[98:].values[0, 3:-1]
male2023[male2023 == '-'] = 0
male2023 = male2023.astype(int)

female2023 = df[195:].values[0, 3:-1]
female2023[female2023 == '-'] = 0
female2023 = female2023.astype(int)

df
# Out:
#                           Unnamed: 0  Всего До 1 года 1 год 2 года 3 года  \
# 0                  Мужчины и женщины    NaN       NaN   NaN    NaN    NaN
# 1              Российская Федерация   16561         3     -      -      -
# 2      Центральный федеральный округ   2707         2     -      -      -
# 3               Белгородская область     35         -     -      -      -
# 4                   Брянская область     54         -     -      -      -
# ..                               ...    ...       ...   ...    ...    ...
# 286                 Амурская область      8         -     -      -      -
# 287              Магаданская область      1         -     -      -      -
# 288              Сахалинская область      7         -     -      -      -
# 289     Еврейская автономная область      5         -     -      -      -
# 290       Чукотский автономный округ      6         -     -      -      -
#
#     4 года 5 лет 6 лет 7 лет  ... 92 лет 93 лет 94 лет 95 лет 96 лет 97 лет  \
# 0      NaN   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 1        2     1     1     -  ...      -      -      -      -      -      -
# 2        1     -     -     -  ...      -      -      -      -      -      -
# 3        -     -     -     -  ...      -      -      -      -      -      -
# 4        -     -     -     -  ...      -      -      -      -      -      -
# ..     ...   ...   ...   ...  ...    ...    ...    ...    ...    ...    ...
# 286      -     -     -     -  ...      -      -      -      -      -      -
# 287      -     -     -     -  ...      -      -      -      -      -      -
# 288      -     -     -     -  ...      -      -      -      -      -      -
# 289      -     -     -     -  ...      -      -      -      -      -      -
# 290      -     -     -     -  ...      -      -      -      -      -      -
#
#     98 лет 99 лет 100 и более Неизвестно
# 0      NaN    NaN         NaN        NaN
# 1        -      -           -         53
# 2        -      -           -         38
# 3        -      -           -          -
# 4        -      -           -          -
# ..     ...    ...         ...        ...
# 286      -      -           -          -
# 287      -      -           -          -
# 288      -      -           -          -
# 289      -      -           -          -
# 290      -      -           -          -
#
# [291 rows x 104 columns]

# %%
# Merge two files

male = np.concatenate((male, male2023[:, np.newaxis]), axis=1)
female = np.concatenate((female, female2023[:, np.newaxis]), axis=1)

years = np.arange(2006, 2024)

# %%
cm = plt.cm.viridis(np.linspace(0, .9, 2023 - 2006 + 1))

fig = plt.figure(figsize=(6, 2.5))

plt.subplot(131)
plt.gca().set_prop_cycle('color', list(cm))
plt.plot(age, male)

modes_male = np.zeros(years.size).astype(int)
for i, y in enumerate(years):
    mode = np.argmax(male[:, i])
    modes_male[i] = mode
    plt.plot(age[mode], male[mode, i], '.', markersize=6)

plt.xlim([20, 60])
plt.ylim([0, 1000])
plt.xlabel('Age')
plt.ylabel('HIV deaths')
plt.title('Male HIV deaths')

plt.subplot(132)
plt.gca().set_prop_cycle('color', list(cm))
plt.plot(age, female)

modes_female = np.zeros(years.size).astype(int)
for i, y in enumerate(years):
    mode = np.argmax(female[:, i])
    modes_female[i] = mode
    plt.plot(age[mode], female[mode, i], '.', markersize=6)
    
plt.xlim([20, 60])
plt.ylim([0, 1000])
plt.xlabel('Age')
plt.title('Female HIV deaths')

cb = plt.axes([.6, .5, .01, .2])
from matplotlib.colors import LinearSegmentedColormap
cmap = LinearSegmentedColormap.from_list('viridis_cropped', cm)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=2006, vmax=2023))
plt.colorbar(sm, cax=cb, ticks=[2006, 2023])

plt.subplot(166)
plt.plot(years, years - age[modes_male],   'v-', label='Males', markersize=3)
plt.plot(years, years - age[modes_female], '^-', label='Females', markersize=3)
plt.legend()
plt.xticks([2010, 2015, 2020])
plt.xlabel('Year')
plt.ylabel('Cohort with most HIV deaths')
plt.title('Cohorts')

fig.text(.01, .96, 'a', fontsize=8, weight='bold')
fig.text(.36, .96, 'b', fontsize=8, weight='bold')
fig.text(.77, .96, 'c', fontsize=8, weight='bold')

plt.savefig('figures/hiv.png', dpi=200)
plt.savefig('figures/hiv.pdf')
